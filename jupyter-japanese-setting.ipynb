# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ファイルで指定する場合は以下のようにファイルまでのパスを指定する
from matplotlib.font_manager import FontProperties
fp = FontProperties(fname=r'/Users/shotakikuchi/Library/Fonts/ipaexg.ttf', size=14)

# %%
x = np.linspace(-np.pi, np.pi, 101)
plt.plot(x, np.cos(x))

#fontpropertiesを明示的に指定する
plt.title("コサインカーブ", fontproperties=fp)
plt.xlabel("x軸", fontproperties=fp)
plt.ylabel("y軸", fontproperties=fp)
# Out:
# Text(0,0.5,'y軸')
# /Users/shotakikuchi/.pyenv/versions/3.5.1/envs/data_analysis_3.5.1/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
